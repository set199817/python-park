# %%
from random import randint


def sort_win(array):
    for i in range(len(array)):
        for j in range(len(array)):
            if(array[i][1]['Points'] > array[j][1]['Points']):
                array[i], array[j] = array[j], array[i]
    
    print(' # Team name           Win  Lose  Draw Scored Missed Points')
    
    for i in range(len(array)):
        print('{:2d} {:20s} {:2d} {:5d} {:5d} {:6d} {:6d} {:6d}'. format(i + 1, 
                                                                         array[i][0], 
                                                                         array[i][1]['Win'], 
                                                                         array[i][1]['Lose'],
                                                                         array[i][1]['Draw'],
                                                                         array[i][1]['Scored'],
                                                                         array[i][1]['Missed'],
                                                                         array[i][1]['Points']))
        
        
def print_game(array, first_team, second_team):
    flag = 0
    for i in range(len(array)):
        if((array[i][0] == first_team and array[i][1] == second_team) or 
                (array[i][0] == second_team and array[i][1] == first_team)):
            print('{:s} - {:s} {:1d}:{:1d}'.format(array[i][0], array[i][1], array[i][2][0], array[i][2][1]))
            flag = 1
            
    if(flag == 0):
        print("No such games, check your input")



Teams = [['BayernMunich', {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}],
         ['RealMadrid', {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}],
         ['ParisSaintGermain', {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}],
         ['InterMilan', {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}],
         ['Juventus', {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}],
         ['Atletico', {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}]]


Teams_test = [{'BayernMunich': {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}},
         {'RealMadrid': {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}},
         {'ParisSaintGermain': {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}},
         {'InterMilan': {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}},
         {'Juventus': {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}},
         {'Atletico': {'Win': 0, 'Lose': 0, 'Draw': 0, 'Scored': 0, 'Missed': 0, 'Points': 0}}]

        
games = []
         
for i in range(len(Teams)):
    for j in range(len(Teams)):
        
        first_team = Teams[i][0]
        second_team = Teams[j][0]
        
        if(first_team != second_team):
            flag = 0
            for elem in games:
                if(elem[0] == second_team and elem[1] == first_team):
                    flag = 1
                
            if(flag == 0):
                first_score = randint(0,9)
                second_score = randint(0,9)
                
                Teams[i][1]['Scored'] += first_score
                Teams[i][1]['Missed'] += second_score
                Teams[j][1]['Scored'] += second_score
                Teams[j][1]['Missed'] += first_score
                
                if(first_score > second_score):
                    Teams[i][1]['Win'] += 1
                    Teams[j][1]['Lose'] += 1
                    
                    Teams[i][1]['Points'] += 3
                    
                elif(first_score < second_score):
                    Teams[i][1]['Lose'] += 1
                    Teams[j][1]['Win'] += 1
                    
                    Teams[j][1]['Points'] += 3
                    
                else:
                    Teams[i][1]['Draw'] += 1
                    Teams[j][1]['Draw'] += 1
                    
                    Teams[i][1]['Points'] += 1
                    Teams[j][1]['Points'] += 1
                  
                games.append([first_team, second_team, (first_score, second_score)])
                

sort_win(Teams)


print()


choice = None

while(choice != '0'):
    print(
    '''
Make your choice:

1 - Input team names
0 - Exit
    ''')
    
    choice = input()
    print()
    
    if(choice == '1'):
        first_team = input("First team: ")
        second_team = input("Second team: ")
        print()
    
        print_game(games, first_team, second_team)
# Out:
#  # Team name           Win  Lose  Draw Scored Missed Points
#  1 ParisSaintGermain     5     0     0     32      4     15
#  2 RealMadrid            3     1     1     29     22     10
#  3 InterMilan            3     2     0     23     21      9
#  4 Atletico              2     3     0     21     27      6
#  5 BayernMunich          1     3     1     17     30      4
#  6 Juventus              0     5     0     15     33      0
#
#
# Make your choice:
#
# 1 - Input team names
# 0 - Exit
#
# 1
#
# First team: Juventus
# Second team: Atletico
#
# Juventus - Atletico 7:8
#
# Make your choice:
#
# 1 - Input team names
# 0 - Exit
#
# 1
#
# First team: asd
# Second team: ad
#
# No such games, check your input
#
# Make your choice:
#
# 1 - Input team names
# 0 - Exit
